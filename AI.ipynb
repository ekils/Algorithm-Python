# %% [markdown]
# <a href="https://colab.research.google.com/github/ekils/Algorithm-Python/blob/master/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# xxxx
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.0.0-beta1'

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# ··········

# %%
from google.colab import files

# %%
# !mkdir -p Drive
# !google-drive-ocamlfuse Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive"
# Out:
#  20181121.gslides
#  boy_high_school.gsheet
#  CLV_for_Presentation.gslides
#  CLV.gslides
#  ColabNotebooks
# 'Content Based Intelligent Cropping '
# 'Data Analytics 熱賣品牌與熱搜度預測系統.gslides'
#  eng_name1.gsheet
#  eng_name2.gsheet
#  GAN
#  girl_high_school.gsheet
# 'learnopencv : Homography'
#  MEMO.gdoc
#  News.aspx
#  ReinforcementLearning.gslides
#  sample_images.gz
#  分群2.0.gslides
#  分群2.0.pdf
#  商品影像AI辨識_初賽測試資料
# '客戶分群(編輯版).gslides'
#  推薦系統2.0.gslides
#  推薦系統.gslides
# '未命名的 Jam'
#  無標題的試算表.gsheet
#  精準行銷.gdoc
#  結婚側拍
#  蜜月
# '螢幕快照 2019-04-08 下午10.56.01.png'
# '螢幕快照 2019-04-08 下午10.57.10.png'

# %%
# !tar -xvf "/content/drive/My Drive/商品影像AI
1
​
2
! ls '/content/drive/My Drive/商品影像AI辨識_初賽測試資料'

[ ]
1
from google.colab import drive
2
drive.mount('/content/drive')
[30]
1
! apt-get install p7zip-full

[ ]
1
​
001.png
辨識_初賽測試資料/初賽測試影像資料_ver0717.tar"
# Out:
# 初賽測試影像資料_ver0717/
# 初賽測試影像資料_ver0717/001.png
# 初賽測試影像資料_ver0717/001.xml
# 初賽測試影像資料_ver0717/002.png
# 初賽測試影像資料_ver0717/002.xml
# 初賽測試影像資料_ver0717/003.png
# 初賽測試影像資料_ver0717/003.xml
# 初賽測試影像資料_ver0717/004.png
# 初賽測試影像資料_ver0717/004.xml
# 初賽測試影像資料_ver0717/005.png
# 初賽測試影像資料_ver0717/005.xml
# 初賽測試影像資料_ver0717/006.png
# 初賽測試影像資料_ver0717/006.xml
# 初賽測試影像資料_ver0717/007.png
# 初賽測試影像資料_ver0717/007.xml
# 初賽測試影像資料_ver0717/008.png
# 初賽測試影像資料_ver0717/008.xml
# 初賽測試影像資料_ver0717/009.png
# 初賽測試影像資料_ver0717/009.xml
# 初賽測試影像資料_ver0717/010.png
# 初賽測試影像資料_ver0717/010.xml
# 初賽測試影像資料_ver0717/011.png
# 初賽測試影像資料_ver0717/011.xml
# 初賽測試影像資料_ver0717/012.png
# 初賽測試影像資料_ver0717/012.xml
# 初賽測試影像資料_ver0717/013.png
# 初賽測試影像資料_ver0717/013.xml
# 初賽測試影像資料_ver0717/014.png
# 初賽測試影像資料_ver0717/014.xml
# 初賽測試影像資料_ver0717/015.png
# 初賽測試影像資料_ver0717/015.xml
# 初賽測試影像資料_ver0717/016.png
# 初賽測試影像資料_ver0717/016.xml
# 初賽測試影像資料_ver0717/017.png
# 初賽測試影像資料_ver0717/017.xml
# 初賽測試影像資料_ver0717/018.png
# 初賽測試影像資料_ver0717/018.xml
# ...

# %%
! ls '/content/drive/My Drive/商品影像AI辨識_初賽測試資料'
# Out:
# readme.txt.gdoc  初賽測試影像資料_ver0717.tar

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! apt-get install p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
! ls
# Out:
# drive  sample_data

# %%
path = os.getcwd() + '/drive/My Drive/test_boundary/'

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img_ori = cv2.imread(path + 'c1.png')
img_ori = cv2.resize(img_ori, (300,300))
img = img_ori[:,:,::-1] #to rgb
_ = plt.imshow(img)
img_gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

img_g = cv2.GaussianBlur(img_gray,(3,3),0)

plt.show()

can = cv2.Canny(img_g,50,150)


plt.imshow(can, cmap='gray')



# img_blur = cv2.GaussianBlur(img_gray,(5,5),0)

# sigma = 10
# v = np.median(img_blur)
# # apply automatic Canny edge detection using the computed median
# lower = int(max(0, (1.0 - sigma) * v))
# upper = int(min(255, (1.0 + sigma) * v))

# can = cv2.Canny(img_blur,lower,upper)
# plt.subplots(figsize=(15,8))
# plt.imshow(can,cmap='gray')








plt.show()

imgx, contour, _  = cv2.findContours(can.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
i_copy = img.copy()
_ = cv2.drawContours(i_copy,contour,-1, (0, 255, 0), 2) # -1 不指定畫圖型態, (r,g,b),線粗細
_ = plt.imshow(i_copy)


plt.show()
import numpy as np
i_copy3 = img.copy()
for c in contour:
    box = cv2.minAreaRect(c)
    box = np.int0(cv2.boxPoints(box))# 省略小數點後面
    _ = cv2.drawContours(i_copy3,[box],-1, (0, 255, 0), 2) 

_ = plt.imshow(i_copy3)

# %%
img_ori = cv2.imread(path + 'c1.png')
img_ori = cv2.resize(img_ori, (300,300))
img_ori = img_ori[:,:,::-1] # to RGB
plt.imshow(img_ori,cmap='gray')
plt.show()
img_gray = cv2.cvtColor(img_ori,cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray,cmap='gray')

# %%
img_blur = cv2.GaussianBlur(img_gray,(1,1),0)

img_canny = cv2.Canny(img_blur,10,100)
plt.imshow(img_canny,cmap='gray')
# sigma = 400
# v = np.median(img_blur)
# # apply automatic Canny edge detection using the computed median
# lower = int(max(0, (1.0 - sigma) * v))
# upper = int(min(255, (1.0 + sigma) * v))

# img_canny = cv2.Canny(img_blur,lower,upper)
# plt.subplots(figsize=(15,8))
# plt.imshow(img_canny,cmap='gray')

# %%
iii, cnts, _ = cv2.findContours(img_canny.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
img_text = img_ori.copy()
cnts = sorted(cnts, key=cv2.contourArea, reverse=True)[:7]
for i,c in enumerate(cnts):
    peri = cv2.arcLength(c,True)
    approx = cv2.approxPolyDP(c, peri * 0.01 ,True)
    if len(approx)==4 and i == 0:
        print('here')
        _ = cv2.drawContours(img_text,[c],-1, (0, 255, 0), 2) # -1 不指定畫圖型態, (r,g,b),線粗細
    else:
        print('.....')
plt.subplots(figsize=(15,8))
plt.imshow(img_text)
plt.show()
# Out:
# .....
# .....
# .....
# .....
# .....
# .....
# .....
